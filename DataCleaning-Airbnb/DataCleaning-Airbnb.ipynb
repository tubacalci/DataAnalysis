# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("Airbnb_Open_Data.csv")
data.head()
# Out:
# C:\Users\tubac\AppData\Local\Temp\ipykernel_14920\1113942449.py:1: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("Airbnb_Open_Data.csv")
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# ...

# %%
data.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102599 entries, 0 to 102598
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              102599 non-null  int64
#  1   NAME                            102349 non-null  object
#  2   host id                         102599 non-null  int64
#  3   host_identity_verified          102310 non-null  object
#  4   host name                       102193 non-null  object
#  5   neighbourhood group             102570 non-null  object
#  6   neighbourhood                   102583 non-null  object
#  7   lat                             102591 non-null  float64
#  8   long                            102591 non-null  float64
#  9   country                         102067 non-null  object
#  10  country code                    102468 non-null  object
#  11  instant_bookable                102494 non-null  object
# ...

# %%
data["license"]
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 102594    NaN
# 102595    NaN
# 102596    NaN
# 102597    NaN
# 102598    NaN
# Name: license, Length: 102599, dtype: object

# %% [markdown]
# ---
# * Deleting redundant columns.
# * Renaming the columns.
# * Dropping duplicates.
# * Remove the NaN values from the dataset
# * Cleaning individual columns.
# * Check for some more Transformations
# ---

# %%
data.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license'],
#       dtype='object')

# %%
columns_to_keep = ['NAME', 'host id', 'host_identity_verified', 'host name',
'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
'country code', 'instant_bookable', 'cancellation_policy', 'room type',
'Construction year', 'price', 'service fee', 'minimum nights',
'number of reviews', 'last review']
columns_to_drop = ['reviews per month',
'review rate number', 'calculated host listings count',
'availability 365', 'house_rules', 'license', 'id']

# %%
len(columns_to_keep)
# Out:
# 19

# %%
len(columns_to_drop)
# Out:
# 7

# %% [markdown]
# # 1st Method, Filtering Data

# %%
df = data[columns_to_keep]
df
# Out:
#                                                     NAME      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                                    NaN  85098326012
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                  ...          ...
# 102594                        Spare room in Williamsburg  12312296767
# 102595                     Best Location near Columbia U  77864383453
# 102596                    Comfy, bright room in Brooklyn  69050334417
# 102597                  Big Studio-One Stop from Midtown  11160591270
# 102598                              585 sf Luxury Studio  68170633372
#
#        host_identity_verified    host name neighbourhood group  \
# ...

# %% [markdown]
# # 2nd Method, Dropping Columns

# %%
data.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license'],
#       dtype='object')

# %%
data.drop(columns = columns_to_drop, inplace = True)

# %%
data.shape
# Out:
# (102599, 19)

# %% [markdown]
# ## Renaming the columns

# %%
data.rename(columns = {"NAME":"Name"}, inplace = True)

# %%
data.columns
# Out:
# Index(['Name', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review'],
#       dtype='object')

# %%
new_column_names = []

for i in data.columns:
    new_column_names.append(i.upper())

# %%
new_column_names
# Out:
# ['NAME',
#  'HOST ID',
#  'HOST_IDENTITY_VERIFIED',
#  'HOST NAME',
#  'NEIGHBOURHOOD GROUP',
#  'NEIGHBOURHOOD',
#  'LAT',
#  'LONG',
#  'COUNTRY',
#  'COUNTRY CODE',
#  'INSTANT_BOOKABLE',
#  'CANCELLATION_POLICY',
#  'ROOM TYPE',
#  'CONSTRUCTION YEAR',
#  'PRICE',
#  'SERVICE FEE',
#  'MINIMUM NIGHTS',
#  'NUMBER OF REVIEWS',
#  'LAST REVIEW']

# %%
new_dataframe_to_modify = data.copy()

# %%
new_dataframe_to_modify.columns = new_column_names

# %%
new_dataframe_to_modify.columns
# Out:
# Index(['NAME', 'HOST ID', 'HOST_IDENTITY_VERIFIED', 'HOST NAME',
#        'NEIGHBOURHOOD GROUP', 'NEIGHBOURHOOD', 'LAT', 'LONG', 'COUNTRY',
#        'COUNTRY CODE', 'INSTANT_BOOKABLE', 'CANCELLATION_POLICY', 'ROOM TYPE',
#        'CONSTRUCTION YEAR', 'PRICE', 'SERVICE FEE', 'MINIMUM NIGHTS',
#        'NUMBER OF REVIEWS', 'LAST REVIEW'],
#       dtype='object')

# %% [markdown]
# ## Dropping duplicates

# %%
data.duplicated().sum()
# Out:
# 541

# %%
data.drop_duplicates(inplace = True)

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Remove the NaN values from the dataset

# %%
data.isna().sum()
# Out:
# Name                        250
# host id                       0
# host_identity_verified      289
# host name                   404
# neighbourhood group          29
# neighbourhood                16
# lat                           8
# long                          8
# country                     532
# country code                131
# instant_bookable            105
# cancellation_policy          76
# room type                     0
# Construction year           214
# price                       247
# service fee                 273
# minimum nights              400
# number of reviews           183
# last review               15832
# dtype: int64

# %%
data.dropna(inplace = True)

# %%
data.isna().sum()
# Out:
# Name                      0
# host id                   0
# host_identity_verified    0
# host name                 0
# neighbourhood group       0
# neighbourhood             0
# lat                       0
# long                      0
# country                   0
# country code              0
# instant_bookable          0
# cancellation_policy       0
# room type                 0
# Construction year         0
# price                     0
# service fee               0
# minimum nights            0
# number of reviews         0
# last review               0
# dtype: int64

# %% [markdown]
# ## Cleaning individual columns

# %%
data["host_identity_verified"].str.upper()
# Out:
# 0         UNCONFIRMED
# 1            VERIFIED
# 4            VERIFIED
# 5            VERIFIED
# 7         UNCONFIRMED
#              ...
# 102029    UNCONFIRMED
# 102030       VERIFIED
# 102031       VERIFIED
# 102032    UNCONFIRMED
# 102040       VERIFIED
# Name: host_identity_verified, Length: 83969, dtype: object

# %%
data["host_identity_verified"] = data["host_identity_verified"].str.upper()

# %%
data["host_identity_verified"].unique()
# Out:
# array(['UNCONFIRMED', 'VERIFIED'], dtype=object)

# %%
data["host_identity_verified"] = data["host_identity_verified"].map({"UNCONFIRMED": 0, "VERIFIED": 1})

# %%
data["host_identity_verified"]
# Out:
# 0        0
# 1        1
# 2        1
# 3        1
# 4        0
#         ..
# 83964    0
# 83965    1
# 83966    1
# 83967    0
# 83968    1
# Name: host_identity_verified, Length: 83969, dtype: int64

# %%
data["host_identity_verified"].value_counts()
# Out:
# host_identity_verified
# 0    42010
# 1    41959
# Name: count, dtype: int64

# %%
data
# Out:
#         index                                              Name      host id  \
# 0           0                Clean & quiet apt home by the park  80014485718
# 1           1                             Skylit Midtown Castle  52335172823
# 2           4  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 3           5         Large Cozy 1 BR Apartment In Midtown East  45498551794
# 4           7                                   BlissArtsSpace!  90821839709
# ...       ...                                               ...          ...
# 83964  102029            Cozy room in a 2B with backyard access   5155155913
# 83965  102030                      An East Williamsburg Delight  71564706996
# 83966  102031                      Cozy bedroom in williamsburg  83101851929
# 83967  102032                            Spacious Room w/ 2 Bed  69037598918
# 83968  102040                     Room in Queens, NY, near LGA.  56457739998
#
# ...

# %%
# data["instant_bookable"] = data["instant_bookable"].map({"t": 1, "f": 0})

# %%
data["instant_bookable"].apply(lambda x: 1 if x == True else 0)
# Out:
# 0         0
# 1         0
# 4         0
# 5         1
# 7         0
#          ..
# 102029    0
# 102030    1
# 102031    1
# 102032    0
# 102040    1
# Name: instant_bookable, Length: 83969, dtype: int64

# %%
data["instant_bookable"] = data["instant_bookable"].apply(lambda x: 1 if x == True else 0)

# %%
data.reset_index(inplace = True)

# %%
data
# Out:
#         index                                              Name      host id  \
# 0           0                Clean & quiet apt home by the park  80014485718
# 1           1                             Skylit Midtown Castle  52335172823
# 2           4  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 3           5         Large Cozy 1 BR Apartment In Midtown East  45498551794
# 4           7                                   BlissArtsSpace!  90821839709
# ...       ...                                               ...          ...
# 83964  102029            Cozy room in a 2B with backyard access   5155155913
# 83965  102030                      An East Williamsburg Delight  71564706996
# 83966  102031                      Cozy bedroom in williamsburg  83101851929
# 83967  102032                            Spacious Room w/ 2 Bed  69037598918
# 83968  102040                     Room in Queens, NY, near LGA.  56457739998
#
# ...

# %%
data["price"].head(3)
# Out:
# 0    $966
# 1    $142
# 2    $204
# Name: price, dtype: object

# %%
data["price"] = data["price"].str.replace("$", "")

# %%
data["price"]
# Out:
# 0          966
# 1          142
# 2          204
# 3          577
# 4        1,060
#           ...
# 83964      822
# 83965      455
# 83966    1,078
# 83967      103
# 83968      982
# Name: price, Length: 83969, dtype: object

# %%
data["price"] = data["price"].str.replace(",", "")

# %%
data["price"]
# Out:
# 0         966
# 1         142
# 2         204
# 3         577
# 4        1060
#          ...
# 83964     822
# 83965     455
# 83966    1078
# 83967     103
# 83968     982
# Name: price, Length: 83969, dtype: object

# %%
data["price"][15]
# Out:
# '370 '

# %%
data["price"] = data["price"].str.replace(" ", "")

# %%
data["price"][15]
# Out:
# '370'

# %%
data["price"]
# Out:
# 0         966
# 1         142
# 2         204
# 3         577
# 4        1060
#          ...
# 83964     822
# 83965     455
# 83966    1078
# 83967     103
# 83968     982
# Name: price, Length: 83969, dtype: object

# %%
data["price"].astype(int)
# Out:
# 0         966
# 1         142
# 2         204
# 3         577
# 4        1060
#          ...
# 83964     822
# 83965     455
# 83966    1078
# 83967     103
# 83968     982
# Name: price, Length: 83969, dtype: int32

# %%
type(data["price"][1])
# Out:
# str

# %%
type(data["price"].astype(int)[1])
# Out:
# numpy.int32

# %%
data["price"] = data["price"].astype(int)

# %%
type(data["price"][1])
# Out:
# numpy.int32

# %%
data["service fee"] = data["service fee"].str.replace("$", "")

# %%
data["service fee"]
# Out:
# 0        193
# 1         28
# 2         41
# 3        115
# 4        212
#          ...
# 83964    164
# 83965     91
# 83966    216
# 83967     21
# 83968    196
# Name: service fee, Length: 83969, dtype: object

# %%
data["service fee"] = data["service fee"].astype(int)

# %%
data
# Out:
#         index                                              Name      host id  \
# 0           0                Clean & quiet apt home by the park  80014485718
# 1           1                             Skylit Midtown Castle  52335172823
# 2           4  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 3           5         Large Cozy 1 BR Apartment In Midtown East  45498551794
# 4           7                                   BlissArtsSpace!  90821839709
# ...       ...                                               ...          ...
# 83964  102029            Cozy room in a 2B with backyard access   5155155913
# 83965  102030                      An East Williamsburg Delight  71564706996
# 83966  102031                      Cozy bedroom in williamsburg  83101851929
# 83967  102032                            Spacious Room w/ 2 Bed  69037598918
# 83968  102040                     Room in Queens, NY, near LGA.  56457739998
#
# ...

# %%
data["last review"]
# Out:
# 0        10/19/2021
# 1         5/21/2022
# 2        11/19/2018
# 3         6/22/2019
# 4         10/5/2017
#             ...
# 83964     4/25/2019
# 83965     6/27/2018
# 83966     6/10/2019
# 83967     6/23/2019
# 83968     6/29/2019
# Name: last review, Length: 83969, dtype: object

# %%
data["last review"] = pd.to_datetime(data["last review"])

# %%
data["last review"]
# Out:
# 0       2021-10-19
# 1       2022-05-21
# 2       2018-11-19
# 3       2019-06-22
# 4       2017-10-05
#            ...
# 83964   2019-04-25
# 83965   2018-06-27
# 83966   2019-06-10
# 83967   2019-06-23
# 83968   2019-06-29
# Name: last review, Length: 83969, dtype: datetime64[ns]

# %%
data
# Out:
#         index                                              Name      host id  \
# 0           0                Clean & quiet apt home by the park  80014485718
# 1           1                             Skylit Midtown Castle  52335172823
# 2           4  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 3           5         Large Cozy 1 BR Apartment In Midtown East  45498551794
# 4           7                                   BlissArtsSpace!  90821839709
# ...       ...                                               ...          ...
# 83964  102029            Cozy room in a 2B with backyard access   5155155913
# 83965  102030                      An East Williamsburg Delight  71564706996
# 83966  102031                      Cozy bedroom in williamsburg  83101851929
# 83967  102032                            Spacious Room w/ 2 Bed  69037598918
# 83968  102040                     Room in Queens, NY, near LGA.  56457739998
#
# ...

# %%
data["cancellation_policy"]
# Out:
# 0          strict
# 1        moderate
# 2        moderate
# 3        flexible
# 4        moderate
#            ...
# 83964    flexible
# 83965    moderate
# 83966    flexible
# 83967    moderate
# 83968      strict
# Name: cancellation_policy, Length: 83969, dtype: object

# %%
order = {"strict": 2, "moderate": 1, "flexible": 0}
data["cancellation_policy"] = data["cancellation_policy"].map(order)

# %%
data["cancellation_policy"]
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 83964   NaN
# 83965   NaN
# 83966   NaN
# 83967   NaN
# 83968   NaN
# Name: cancellation_policy, Length: 83969, dtype: float64

# %%
data
# Out:
#         index                                              Name      host id  \
# 0           0                Clean & quiet apt home by the park  80014485718
# 1           1                             Skylit Midtown Castle  52335172823
# 2           4  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 3           5         Large Cozy 1 BR Apartment In Midtown East  45498551794
# 4           7                                   BlissArtsSpace!  90821839709
# ...       ...                                               ...          ...
# 83964  102029            Cozy room in a 2B with backyard access   5155155913
# 83965  102030                      An East Williamsburg Delight  71564706996
# 83966  102031                      Cozy bedroom in williamsburg  83101851929
# 83967  102032                            Spacious Room w/ 2 Bed  69037598918
# 83968  102040                     Room in Queens, NY, near LGA.  56457739998
#
# ...

# %%
from datetime import datetime

current_year = datetime.now().year
current_year
# Out:
# 2025

# %%
data["Building Age"] = current_year - data["Construction year"]

# %%
data
# Out:
#         index                                              Name      host id  \
# 0           0                Clean & quiet apt home by the park  80014485718
# 1           1                             Skylit Midtown Castle  52335172823
# 2           4  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 3           5         Large Cozy 1 BR Apartment In Midtown East  45498551794
# 4           7                                   BlissArtsSpace!  90821839709
# ...       ...                                               ...          ...
# 83964  102029            Cozy room in a 2B with backyard access   5155155913
# 83965  102030                      An East Williamsburg Delight  71564706996
# 83966  102031                      Cozy bedroom in williamsburg  83101851929
# 83967  102032                            Spacious Room w/ 2 Bed  69037598918
# 83968  102040                     Room in Queens, NY, near LGA.  56457739998
#
# ...

# %%
data["Building Age"].describe()
# Out:
# count    83969.000000
# mean        12.512439
# std          5.761698
# min          3.000000
# 25%          8.000000
# 50%         13.000000
# 75%         18.000000
# max         22.000000
# Name: Building Age, dtype: float64

# %%
# Create a new column 'Age Category' by binning the 'Building Age' values

data["Age Category"] = pd.cut(
    data["Building Age"], # The numerical column to be categorized
    bins = [0,10,30,50],  # Define age intervals: 0–10, 10–30, 30–50
    labels = ["new", "moderate", "old"] # Labels for each age group
)

# %%
data["Age Category"]
# Out:
# 0             new
# 1        moderate
# 2        moderate
# 3        moderate
# 4        moderate
#            ...
# 83964         new
# 83965         new
# 83966         new
# 83967    moderate
# 83968         new
# Name: Age Category, Length: 83969, dtype: category
# Categories (3, object): ['new' < 'moderate' < 'old']

# %%
data
# Out:
#         index                                              Name      host id  \
# 0           0                Clean & quiet apt home by the park  80014485718
# 1           1                             Skylit Midtown Castle  52335172823
# 2           4  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 3           5         Large Cozy 1 BR Apartment In Midtown East  45498551794
# 4           7                                   BlissArtsSpace!  90821839709
# ...       ...                                               ...          ...
# 83964  102029            Cozy room in a 2B with backyard access   5155155913
# 83965  102030                      An East Williamsburg Delight  71564706996
# 83966  102031                      Cozy bedroom in williamsburg  83101851929
# 83967  102032                            Spacious Room w/ 2 Bed  69037598918
# 83968  102040                     Room in Queens, NY, near LGA.  56457739998
#
# ...

# %%
data.to_csv("cleaned_data.csv")

# %%
pd.read_csv("cleaned_data.csv")
# Out:
#        Unnamed: 0   index                                              Name  \
# 0               0       0                Clean & quiet apt home by the park
# 1               1       1                             Skylit Midtown Castle
# 2               2       4  Entire Apt: Spacious Studio/Loft by central park
# 3               3       5         Large Cozy 1 BR Apartment In Midtown East
# 4               4       7                                   BlissArtsSpace!
# ...           ...     ...                                               ...
# 83964       83964  102029            Cozy room in a 2B with backyard access
# 83965       83965  102030                      An East Williamsburg Delight
# 83966       83966  102031                      Cozy bedroom in williamsburg
# 83967       83967  102032                            Spacious Room w/ 2 Bed
# 83968       83968  102040                     Room in Queens, NY, near LGA.
#
# ...

# %%
data.drop(columns = ["index"], inplace = True)

# %%
data
# Out:
#                                                    Name      host id  \
# 0                    Clean & quiet apt home by the park  80014485718
# 1                                 Skylit Midtown Castle  52335172823
# 2      Entire Apt: Spacious Studio/Loft by central park  92037596077
# 3             Large Cozy 1 BR Apartment In Midtown East  45498551794
# 4                                       BlissArtsSpace!  90821839709
# ...                                                 ...          ...
# 83964            Cozy room in a 2B with backyard access   5155155913
# 83965                      An East Williamsburg Delight  71564706996
# 83966                      Cozy bedroom in williamsburg  83101851929
# 83967                            Spacious Room w/ 2 Bed  69037598918
# 83968                     Room in Queens, NY, near LGA.  56457739998
#
#        host_identity_verified  host name neighbourhood group  \
# 0                           0   Madaline            Brooklyn
# ...

# %%
data.to_csv("cleaned_data_without_index.csv", index = False)

# %%
pd.read_csv("cleaned_data_without_index.csv")
# Out:
#                                                    Name      host id  \
# 0                    Clean & quiet apt home by the park  80014485718
# 1                                 Skylit Midtown Castle  52335172823
# 2      Entire Apt: Spacious Studio/Loft by central park  92037596077
# 3             Large Cozy 1 BR Apartment In Midtown East  45498551794
# 4                                       BlissArtsSpace!  90821839709
# ...                                                 ...          ...
# 83964            Cozy room in a 2B with backyard access   5155155913
# 83965                      An East Williamsburg Delight  71564706996
# 83966                      Cozy bedroom in williamsburg  83101851929
# 83967                            Spacious Room w/ 2 Bed  69037598918
# 83968                     Room in Queens, NY, near LGA.  56457739998
#
#        host_identity_verified  host name neighbourhood group  \
# 0                           0   Madaline            Brooklyn
# ...

# %%
data.to_excel("excel_cleaned_data.xlsx")

# %%
data.to_excel("excel_cleaned_data_index_false.xlsx", index = False)

# %%
pd.read_excel("excel_cleaned_data.xlsx")
# Out:
#        Unnamed: 0                                              Name  \
# 0               0                Clean & quiet apt home by the park
# 1               1                             Skylit Midtown Castle
# 2               2  Entire Apt: Spacious Studio/Loft by central park
# 3               3         Large Cozy 1 BR Apartment In Midtown East
# 4               4                                   BlissArtsSpace!
# ...           ...                                               ...
# 83964       83964            Cozy room in a 2B with backyard access
# 83965       83965                      An East Williamsburg Delight
# 83966       83966                      Cozy bedroom in williamsburg
# 83967       83967                            Spacious Room w/ 2 Bed
# 83968       83968                     Room in Queens, NY, near LGA.
#
#            host id  host_identity_verified  host name neighbourhood group  \
# 0      80014485718                       0   Madaline            Brooklyn
# ...

# %%
pd.read_excel("excel_cleaned_data_index_false.xlsx")
# Out:
#                                                    Name      host id  \
# 0                    Clean & quiet apt home by the park  80014485718
# 1                                 Skylit Midtown Castle  52335172823
# 2      Entire Apt: Spacious Studio/Loft by central park  92037596077
# 3             Large Cozy 1 BR Apartment In Midtown East  45498551794
# 4                                       BlissArtsSpace!  90821839709
# ...                                                 ...          ...
# 83964            Cozy room in a 2B with backyard access   5155155913
# 83965                      An East Williamsburg Delight  71564706996
# 83966                      Cozy bedroom in williamsburg  83101851929
# 83967                            Spacious Room w/ 2 Bed  69037598918
# 83968                     Room in Queens, NY, near LGA.  56457739998
#
#        host_identity_verified  host name neighbourhood group  \
# 0                           0   Madaline            Brooklyn
# ...
